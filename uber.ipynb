# %% [markdown]
# <a href="https://colab.research.google.com/github/nadamahmoud00/Uber_Analysis/blob/main/uber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Uber_Egypt_Simulated.csv')
df.head()
# Out:
#    Pickup Area      Dropoff Area Pickup Governorate Dropoff Governorate  \
# 0    Ain Shams       Mohandessin              Cairo                Giza
# 1      Zamalek  Fifth Settlement              Cairo               Cairo
# 2    Ain Shams         Nasr City              Cairo               Cairo
# 3    Nasr City             Rehab              Cairo               Cairo
# 4  6th October         Ain Shams               Giza               Cairo
#
#            Pickup Time Day of Week  Hour of Day  Trip Duration (min)  \
# 0  2024-06-28 10:57:00      Friday           10                 3.41
# 1  2024-06-10 12:31:00      Monday           12                29.94
# 2  2024-06-11 20:30:00     Tuesday           20                10.60
# 3  2024-06-11 15:54:00     Tuesday           15                18.31
# 4  2024-06-15 12:02:00    Saturday           12                39.29
#
#    Trip Distance (km)  Fare per km (EGP)  Fare (EGP)  Service Type  \
# ...

# %%
df['Pickup Time'] = pd.to_datetime(df['Pickup Time'])
df.head()
# Out:
#    Pickup Area      Dropoff Area Pickup Governorate Dropoff Governorate  \
# 0    Ain Shams       Mohandessin              Cairo                Giza
# 1      Zamalek  Fifth Settlement              Cairo               Cairo
# 2    Ain Shams         Nasr City              Cairo               Cairo
# 3    Nasr City             Rehab              Cairo               Cairo
# 4  6th October         Ain Shams               Giza               Cairo
#
#           Pickup Time Day of Week  Hour of Day  Trip Duration (min)  \
# 0 2024-06-28 10:57:00      Friday           10                 3.41
# 1 2024-06-10 12:31:00      Monday           12                29.94
# 2 2024-06-11 20:30:00     Tuesday           20                10.60
# 3 2024-06-11 15:54:00     Tuesday           15                18.31
# 4 2024-06-15 12:02:00    Saturday           12                39.29
#
#    Trip Distance (km)  Fare per km (EGP)  Fare (EGP)  Service Type  \
# ...

# %%
df.isnull().sum()
# Out:
# Pickup Area            0
# Dropoff Area           0
# Pickup Governorate     0
# Dropoff Governorate    0
# Pickup Time            0
# Day of Week            0
# Hour of Day            0
# Trip Duration (min)    0
# Trip Distance (km)     0
# Fare per km (EGP)      0
# Fare (EGP)             0
# Service Type           0
# Payment Method         0
# Driver Rating          0
# dtype: int64

# %%
df.dtypes
# Out:
# Pickup Area                    object
# Dropoff Area                   object
# Pickup Governorate             object
# Dropoff Governorate            object
# Pickup Time            datetime64[ns]
# Day of Week                    object
# Hour of Day                     int64
# Trip Duration (min)           float64
# Trip Distance (km)            float64
# Fare per km (EGP)             float64
# Fare (EGP)                    float64
# Service Type                   object
# Payment Method                 object
# Driver Rating                 float64
# dtype: object

# %%
df.describe()
# Out:
#                          Pickup Time  Hour of Day  Trip Duration (min)  \
# count                           7000  7000.000000          7000.000000
# mean   2024-06-16 00:23:07.928571392    11.507143            30.818210
# min              2024-06-01 00:02:00     0.000000             2.810000
# 25%              2024-06-08 13:05:00     6.000000            16.440000
# 50%              2024-06-16 01:54:00    11.000000            29.325000
# 75%              2024-06-23 13:12:45    18.000000            41.872500
# max              2024-06-30 23:57:00    23.000000            87.840000
# std                              NaN     6.893404            17.519705
#
#        Trip Distance (km)  Fare per km (EGP)   Fare (EGP)  Driver Rating
# count         7000.000000        7000.000000  7000.000000    7000.000000
# mean            15.931030           4.248537    67.659276       4.249429
# min              2.000000           3.000069     6.440000       3.500000
# ...

# %%
df['Driver Rating'].value_counts()
# Out:
# Driver Rating
# 4.1    504
# 3.9    502
# 4.7    498
# 3.7    485
# 4.4    479
# 4.6    479
# 3.6    470
# 3.8    464
# 4.5    461
# 4.8    450
# 4.9    447
# 4.3    442
# 4.0    439
# 4.2    423
# 5.0    242
# 3.5    215
# Name: count, dtype: int64

# %%
df['Service Type'].value_counts()
# Out:
# Service Type
# Uber Bus        1773
# UberX           1762
# Uber Scooter    1759
# Uber Comfort    1706
# Name: count, dtype: int64

# %%
df['Payment Method'].value_counts()
# Out:
# Payment Method
# Credit Card    2335
# Wallet         2333
# Cash           2332
# Name: count, dtype: int64

# %%
df.to_csv('Uber_Cleaned.csv', index=False)

# %%
from google.colab import files
files.download('Uber_Cleaned.csv')
